# %% [markdown]
# <a href="https://colab.research.google.com/github/germanpgonzalez/Seminario-de-Lenguagues-Python/blob/master/Actividad2Teoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Enunciado 2:** dado el archivo de registros de jugadas (eventos) de MemPy, mostrar un gráfico con la duración (en tiempo) de las partidas que se juegan los lunes.

# %%
import pandas as pd

data_set = pd.read_csv('/content/datos de prueba mod.csv')

# %%
data_set
# Out:
#     Unnamed: 0      Tiempo  Partida  ...  Palabra    nivel       dias
# 0            0  1621436490        1  ...      NaN    medio      lunes
# 1            1  1621436491        1  ...     CASA    medio     martes
# 2            2  1621436492        1  ...     CASA    medio  miercoles
# 3            3  1621436493        1  ...     CASA    medio     jueves
# 4            4  1621436494        1  ...    PERRO    medio    viernes
# ..         ...         ...      ...  ...      ...      ...        ...
# 89          89  1621449118        7  ...     MESA  difícil     sabado
# 90          90  1621449119        7  ...    PERRO  difícil    domingo
# 91          91  1621449120        7  ...     GATO  difícil      lunes
# 92          92  1621449121        7  ...  MOCHILA  difícil     martes
# 93          93  1621449136        7  ...      NaN  difícil  miercoles
#
# [94 rows x 12 columns]

# %%
lunes = data_set[data_set["dias"] == "lunes"]
lunes
# Out:
#     Unnamed: 0      Tiempo  Partida  ...  Palabra    nivel   dias
# 0            0  1621436490        1  ...      NaN    medio  lunes
# 7            7  1621436497        1  ...     GATO    medio  lunes
# 14          14  1621436504        1  ...    SILLA    medio  lunes
# 21          21  1621436513        2  ...     MESA    fácil  lunes
# 28          28  1621436520        2  ...     GATO    fácil  lunes
# 35          35  1621446325        3  ...     GATO  difícil  lunes
# 42          42  1621446332        3  ...    SILLA  difícil  lunes
# 49          49  1621446339        4  ...     MESA  difícil  lunes
# 56          56  1621446346        4  ...     GATO  difícil  lunes
# 63          63  1621446353        4  ...      NaN  difícil  lunes
# 70          70  1621436560        5  ...     GATO    fácil  lunes
# 77          77  1621436570        6  ...      NaN    medio  lunes
# 84          84  1621436577        6  ...     MESA    medio  lunes
# ...

# %%
data_dibujo = lunes.groupby("Tiempo")["Tiempo"].count()
etiqueta = data_dibujo.keys()
datos = data_dibujo.values

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.pie(datos, explode=None, labels = etiqueta, autopct='%1.1f%%', shadow= True, startangle=90, labeldistance=1.1)
plt.axis('equal')
plt.legend(etiqueta)
plt.title("Duración de partidas que se juegan los lunes")
plt.show()

# %% [markdown]
# **Enunciado adicional:** dado alguno de los datasets elegidos para el trabajo integrador, mostrar una nube de palabras (con la librería wordcloud) con las palabras elegidas para el juego de acuerdo a alguno de los criterios elegidos en su trabajo.  Considerar utilizar la opción de que se puedan repetir las palabras.

# %%
pokemon = pd.read_csv('/content/pokemon.csv', encoding= 'utf-8')
nombres = pokemon["Name"]
nombres = nombres.unique()
nombres
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard',
#        'CharizardMega Charizard X', 'CharizardMega Charizard Y',
#        'Squirtle', 'Wartortle', 'Blastoise', 'BlastoiseMega Blastoise',
#        'Caterpie', 'Metapod', 'Butterfree', 'Weedle', 'Kakuna',
#        'Beedrill', 'BeedrillMega Beedrill', 'Pidgey', 'Pidgeotto',
#        'Pidgeot', 'PidgeotMega Pidgeot', 'Rattata', 'Raticate', 'Spearow',
#        'Fearow', 'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew',
#        'Sandslash', 'Nidoran♀', 'Nidorina', 'Nidoqueen', 'Nidoran♂',
#        'Nidorino', 'Nidoking', 'Clefairy', 'Clefable', 'Vulpix',
#        'Ninetales', 'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat',
#        'Oddish', 'Gloom', 'Vileplume', 'Paras', 'Parasect', 'Venonat',
#        'Venomoth', 'Diglett', 'Dugtrio', 'Meowth', 'Persian', 'Psyduck',
#        'Golduck', 'Mankey', 'Primeape', 'Growlithe', 'Arcanine',
# ...

# %%
from PIL import Image
import numpy as np

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

def plot_cloud(wordcloud):
   plt.figure(figsize=(40, 30))
   plt.imshow(wordcloud)
   plt.axis("off");

text = str(nombres)
wordcloud = WordCloud(width = 300, height = 200, random_state=1, background_color='black', colormap='Set2', collocations=False, stopwords = STOPWORDS).generate(text)

plot_cloud(wordcloud)
